# %% [markdown]
# #Lab 2

# %% [markdown]
# #Purpose:
# Study basic properties of passive transport.

# %% [markdown]
# #Procedure:
# In the laboratory, we will investigate the basic properties of diffusion, osmosis, and differential permeability, The concept of filtration and the effects of tonicity on cells will also be explored.

# %% [markdown]
# #Results:

# %% [markdown]
# #![IMG_0110.jpeg](data:image/jpeg;base64,...)lab 2

# %% [markdown]
# ![IMG_0111.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ![IMG_0112.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# #Discussion:
# Regardless of the size of the object. measured for filtration, the rate of filtration will remain the same.

# %% [markdown]
# #Conlcusion:
# Not only is the thickness of the liquid a factor of permeability but also the filtration device used to filtrate the liquid.
